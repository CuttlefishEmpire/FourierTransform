# %%
from scipy.io import wavfile
import numpy as np

# UPTOWN FUNK CELL

AudioName = "Uptown Funk.wav" # Audio file name
fs, Audiodata = wavfile.read(AudioName) 

Audiodata = np.mean(Audiodata, axis = 1) # Converts from stereo

# Plot the audio signal in time
import matplotlib.pyplot as plt
plt.plot(Audiodata)
plt.title('Audio signal in time - Uptown Funk',size=16)

# Power spectrum
from scipy.fftpack import fft
n = len(Audiodata) 
AudioFreq = fft(Audiodata)
AudioFreq = AudioFreq[0:int(np.ceil((n+1)/2.0))]
MagFreq = np.abs(AudioFreq) # Magnitude
MagFreq = MagFreq / float(n)
MagFreq = MagFreq**2
if n % 2 > 0: # ffte odd 
    MagFreq[1:len(MagFreq)] = MagFreq[1:len(MagFreq)] * 2
else:# fft even
    MagFreq[1:len(MagFreq) -1] = MagFreq[1:len(MagFreq) - 1] * 2 

# Remove negative volumes, scale volumes appropriately
noNegs = 10*np.log10(MagFreq[:len(MagFreq)//4])
noNegs2 = []
for neg in noNegs:
    if neg > 0:
        noNegs2.append(neg)
    else:
        noNegs2.append(0)

plt.figure()
freqAxis = np.arange(0,int(np.ceil((n+1)/2.0)), 1.0) * (fs / n);
parsedFreqAxis = freqAxis[:len(freqAxis)//4]
boundaryListUnparsed = [0]
boundaryList = []
maxList = []
maxElement = 0
for f, v in zip(parsedFreqAxis, noNegs2):
    if v > 25:
        maxList.append(v)
    else:
        for m in maxList:
            if m > maxElement:
                maxElement = m
        if maxElement != 0:
                boundaryListUnparsed.append(int(f))
        maxList = []
        maxElement = 0
for e in range(1, len(boundaryListUnparsed)):
    if boundaryListUnparsed[e] - boundaryListUnparsed[e-1] > 10 or boundaryListUnparsed[e-1] - boundaryListUnparsed[e] > 15:
        boundaryList.append(boundaryListUnparsed[e])
plt.plot(parsedFreqAxis,noNegs2)
plt.xlabel('Frequency (Hz)'); plt.ylabel('Power spectrum (dB)')

plt.show()

# %%
from scipy.io import wavfile # scipy library to read wav files
import numpy as np

# SOLITUDE CELL

AudioName = "Solitude.wav" # Audio File
fs, Audiodata = wavfile.read(AudioName)

Audiodata = np.mean(Audiodata, axis = 1)

# Plot the audio signal in time
import matplotlib.pyplot as plt
plt.plot(Audiodata)
plt.title('Audio signal in time - Solitude',size=16)

# spectrum
from scipy.fftpack import fft # fourier transform
n = len(Audiodata) 
AudioFreq = fft(Audiodata)
AudioFreq = AudioFreq[0:int(np.ceil((n+1)/2.0))] #Half of the spectrum
MagFreq = np.abs(AudioFreq) # Magnitude
MagFreq = MagFreq / float(n)
# power spectrum
MagFreq = MagFreq**2
if n % 2 > 0: # ffte odd 
    MagFreq[1:len(MagFreq)] = MagFreq[1:len(MagFreq)] * 2
else:# fft even
    MagFreq[1:len(MagFreq) -1] = MagFreq[1:len(MagFreq) - 1] * 2 
noNegs = 10*np.log10(MagFreq[:len(MagFreq)//4])
noNegs2 = []
for neg in noNegs:
    if neg > 0:
        noNegs2.append(neg)
    else:
        noNegs2.append(0)
plt.figure()
freqAxis = np.arange(0,int(np.ceil((n+1)/2.0)), 1.0) * (fs / n);
parsedFreqAxis = freqAxis[:len(freqAxis)//4]
# plt.plot(freqAxis/1000.0, 10*np.log10(MagFreq)) #Power spectrum
boundaryListUnparsed = [0]
boundaryList = []
maxList = []
maxElement = 0
for f, v in zip(parsedFreqAxis, noNegs2):
    if v > 15:
        maxList.append(v)
    else:
        for m in maxList:
            if m > maxElement:
                maxElement = m
        if maxElement != 0:
                boundaryListUnparsed.append(int(f))
        maxList = []
        maxElement = 0
for e in range(1, len(boundaryListUnparsed)):
    if boundaryListUnparsed[e] - boundaryListUnparsed[e-1] > 10 or boundaryListUnparsed[e-1] - boundaryListUnparsed[e] > 15:
        boundaryList.append(boundaryListUnparsed[e])
plt.plot(parsedFreqAxis,noNegs2)
plt.xlabel('Frequency (Hz)'); plt.ylabel('Power spectrum (dB)')

plt.show()

# %%
from scipy.io import wavfile # scipy library to read wav files
import numpy as np

# C MAJOR SCALE CELL

AudioName = "c_major_scale.wav" # Audio File
fs, Audiodata = wavfile.read(AudioName)

Audiodata = np.mean(Audiodata, axis = 1)

# Plot the audio signal in time
import matplotlib.pyplot as plt
plt.plot(Audiodata)
plt.title('Audio signal in time - C Major Scale',size=16)

# spectrum
from scipy.fftpack import fft # fourier transform
n = len(Audiodata) 
AudioFreq = fft(Audiodata)
AudioFreq = AudioFreq[0:int(np.ceil((n+1)/2.0))] #Half of the spectrum
MagFreq = np.abs(AudioFreq) # Magnitude
MagFreq = MagFreq / float(n)
# power spectrum
MagFreq = MagFreq**2
if n % 2 > 0: # ffte odd 
    MagFreq[1:len(MagFreq)] = MagFreq[1:len(MagFreq)] * 2
else:# fft even
    MagFreq[1:len(MagFreq) -1] = MagFreq[1:len(MagFreq) - 1] * 2 
noNegs = 10*np.log10(MagFreq[:len(MagFreq)//4])
noNegs2 = []
for neg in noNegs:
    if neg > 0:
        noNegs2.append(neg)
    else:
        noNegs2.append(0)
plt.figure()
freqAxis = np.arange(0,int(np.ceil((n+1)/2.0)), 1.0) * (fs / n);
parsedFreqAxis = freqAxis[:len(freqAxis)//4]
# plt.plot(freqAxis/1000.0, 10*np.log10(MagFreq)) #Power spectrum
boundaryListUnparsed = [0]
boundaryList = []
maxList = []
maxElement = 0
for f, v in zip(parsedFreqAxis, noNegs2):
    if v > 15:
        maxList.append(v)
    else:
        for m in maxList:
            if m > maxElement:
                maxElement = m
        if maxElement != 0:
                boundaryListUnparsed.append(int(f))
        maxList = []
        maxElement = 0
for e in range(1, len(boundaryListUnparsed)):
    if boundaryListUnparsed[e] - boundaryListUnparsed[e-1] > 10 or boundaryListUnparsed[e-1] - boundaryListUnparsed[e] > 15:
        boundaryList.append(boundaryListUnparsed[e])
plt.plot(parsedFreqAxis,noNegs2)
plt.xlabel('Frequency (Hz)'); plt.ylabel('Power spectrum (dB)')

plt.show()

# %%
from scipy.io import wavfile # scipy library to read wav files
import numpy as np

# C NOTE CELL

AudioName = "sole_test_note_C.wav" # Audio File
fs, Audiodata = wavfile.read(AudioName)

Audiodata = np.mean(Audiodata, axis = 1)

# Plot the audio signal in time
import matplotlib.pyplot as plt
plt.plot(Audiodata)
plt.title('Audio signal in time - Sole C Note',size=16)

# spectrum
from scipy.fftpack import fft # fourier transform
n = len(Audiodata) 
AudioFreq = fft(Audiodata)
AudioFreq = AudioFreq[0:int(np.ceil((n+1)/2.0))] #Half of the spectrum
MagFreq = np.abs(AudioFreq) # Magnitude
MagFreq = MagFreq / float(n)
# power spectrum
MagFreq = MagFreq**2
if n % 2 > 0: # ffte odd 
    MagFreq[1:len(MagFreq)] = MagFreq[1:len(MagFreq)] * 2
else:# fft even
    MagFreq[1:len(MagFreq) -1] = MagFreq[1:len(MagFreq) - 1] * 2 
noNegs = 10*np.log10(MagFreq[:len(MagFreq)//4])
noNegs2 = []
for neg in noNegs:
    if neg > 0:
        noNegs2.append(neg)
    else:
        noNegs2.append(0)
plt.figure()
freqAxis = np.arange(0,int(np.ceil((n+1)/2.0)), 1.0) * (fs / n);
parsedFreqAxis = freqAxis[:len(freqAxis)//4]
# plt.plot(freqAxis/1000.0, 10*np.log10(MagFreq)) #Power spectrum
boundaryListUnparsed = [0]
boundaryList = []
maxList = []
maxElement = 0
for f, v in zip(parsedFreqAxis, noNegs2):
    if v > 15:
        maxList.append(v)
    else:
        for m in maxList:
            if m > maxElement:
                maxElement = m
        if maxElement != 0:
                boundaryListUnparsed.append(int(f))
        maxList = []
        maxElement = 0
for e in range(1, len(boundaryListUnparsed)):
    if boundaryListUnparsed[e] - boundaryListUnparsed[e-1] > 10 or boundaryListUnparsed[e-1] - boundaryListUnparsed[e] > 15:
        boundaryList.append(boundaryListUnparsed[e])
plt.plot(parsedFreqAxis,noNegs2)
plt.xlabel('Frequency (Hz)'); plt.ylabel('Power spectrum (dB)')

plt.show()

# %%
from scipy.io import wavfile
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
from scipy.fftpack import fft
from math import log2, pow
from os import listdir

data = open("output.txt","w")
bpms = []
domFrqs = []
lengths = []
keyChanges = []
names = []
octaves = []

def fourierTransform(audName):
    # MASTER
    names.append(audName)
    AudioName = audName # Audio file name
    fs, Audiodata = wavfile.read(AudioName) 
    Audiodata = np.mean(Audiodata, axis = 1) # Converts from stereo

    # Plot the audio signal in time
    plt.plot(Audiodata)
    plt.title(AudioName[AudioName.index("/"):len(AudioName)-4],size=16)
    # Power spectrum
    n = len(Audiodata) 
    AudioFreq = fft(Audiodata)
    AudioFreq = AudioFreq[0:int(np.ceil((n+1)/2.0))]
    MagFreq = np.abs(AudioFreq) # Magnitude
    MagFreq = MagFreq / float(n)
    MagFreq = MagFreq**2
    if n % 2 > 0: # ffte odd 
        MagFreq[1:len(MagFreq)] = MagFreq[1:len(MagFreq)] * 2
    else:# fft even
        MagFreq[1:len(MagFreq) -1] = MagFreq[1:len(MagFreq) - 1] * 2 

    # LIST OF VARIABLES AND WHAT THEY MEAN:
    # - noNegs2: y values of Fourier transform that are positive
    # - parsedFreqAxis: First quarter of the thing the Fourier transform generates
    # - boundaryList: *Supposed* to be the peaks but all that needs a rework

    # The thing that understands frqs to notes
    def pitch(freq):
        A4 = 440
        C0 = A4*pow(2, -4.75)
        name = ["C", "C#", "D", "D#", "E", "F", "F#", "G", "G#", "A", "A#", "B"]
        h = round(12*log2(freq/C0))
        octave = h // 12
        n = h % 12
        return name[n] + str(octave)

    # Remove negative volumes
    noNegs = 10*np.log10(MagFreq[:len(MagFreq)//4])
    noNegs2 = []
    for neg in noNegs:
        if neg > 0:
            noNegs2.append(neg)
        else:
            noNegs2.append(0)
    plt.figure()
    freqAxis = np.arange(0,int(np.ceil((n+1)/2.0)), 1.0) * (fs / n);
    parsedFreqAxis = freqAxis[:len(freqAxis)//4]
    # parsedFreqAxis = np.log10(parsedFreqAxis)

    # Figure out BPM
    parsedFreqAxisTest = []
    for v in parsedFreqAxis:
        parsedFreqAxisTest.append(v/(fs/n))
    lenOfFreqAxis = len(parsedFreqAxis)
    # lenOfBpmAxis = round(len(parsedFreqAxis)*(1/1100))
    lenOfBpmAxis = 0
    for v in range(1, lenOfFreqAxis):
        if(parsedFreqAxis[v] <= 3):
            lenOfBpmAxis = v
    maxHzTest = parsedFreqAxis[lenOfBpmAxis]
    bpmPoss = parsedFreqAxis[round(lenOfBpmAxis/3):lenOfBpmAxis]
    bpmPossVals = noNegs2[round(lenOfBpmAxis/3):lenOfBpmAxis]
    bpmFreq = 0
    maxBpmVol = 0
    bpmFreq = bpmPoss[bpmPossVals.index(max(bpmPossVals))]*60
    indOfBpmFreq = bpmPossVals.index(max(bpmPossVals))
    for f, v in zip(bpmPoss, bpmPossVals):
        if v > maxBpmVol:
        #bpmFreq = f
            maxBpmVol = v
    #bpmFreq = bpmFreq * 60
    bpmFreq0 = int(round(60*bpmPoss[bpmPossVals.index(max(bpmPossVals))]))
    print("BPM:",bpmFreq0)
    bpms.append(bpmFreq0)
    plt.plot(bpmPoss, bpmPossVals)
    plt.xlabel('Frequency (Hz)')
    plt.ylabel('Power spectrum (dB)')
    plt.title('Bpm stuff')
    # What octave is it mainly in (would comment out if I could but since Python is big gay I'll just write a whole new section and ignore this)
    #    numOfOctave = 0
    #topFivePeaks = []
    #    peaks = []
    #peaksVols = []
    #for v in range(10, len(noNegs2)-10):
    #    if (noNegs2[v] > noNegs2[v-10]) and (noNegs2[v] > noNegs2[v+10]) and (noNegs2[v] > noNegs2[v-5]) and (noNegs2[v] > noNegs2[v+5]) and (noNegs2[v] > noNegs2[v-1]) and (noNegs2[v] > noNegs2[v+1]):
            #if parsedFreqAxis[v] > 130:
    #            peaks.append(parsedFreqAxis[v])
    #            peaksVols.append(noNegs2[v])
    #peaksBackup = peaks
    #peaksVolsBackup = peaksVols
    #for v in range(0,5):
    #    maxPeak = 0
    #    indOfMax = 0
    #    for f in range(0,len(peaks)):
    #        if peaksVols[f] > maxPeak:
    #            maxPeak = peaksVols[f]
    #            indOfMax = f
    #    topFivePeaks.append(peaks[indOfMax])
    #    peaks.pop(indOfMax)
    #    peaksVols.pop(indOfMax)

    # What octave is it mainly in, actually this time
    octave = 0
    octaveBounds = [16.35, 32.7, 65.41, 130.81, 261.63, 523.25, 1046.5]
    noNegs3 = noNegs2
    for v in range(1,len(noNegs3)):
        if parsedFreqAxis[v] < 35:
            noNegs3[v] = 0
    dominantFrq = parsedFreqAxis[noNegs3.index(max(noNegs3))]
    dominantFrqPitch = pitch(dominantFrq)
    print("Dominant frequency:",dominantFrq)
    domFrqs.append(dominantFrq)
    print("Pitch of dominant frequency:",dominantFrqPitch)
    for o in range(1,len(octaveBounds)):
        if dominantFrq < octaveBounds[o] and dominantFrq > octaveBounds[o-1]:
            octave = o-1
    print("Octave:",octave)
    octaves.append(octave)

    # Length
    length = Audiodata.shape[0]/fs
    minutes = int(length/60)
    seconds = int(length%60)
    print("Length:",minutes,"min,",seconds,"sec")
    lengths.append(length)

    # # of key changes
    def numOfKeyChanges(audDat):
        keys = []
        x = 0
        numOfSubds = 15
        nKeyDs = 0
        sectionLength = int(len(audDat)/numOfSubds)
        for y in range(numOfSubds):
            print("Working on key change",str(y)+"/"+str(numOfSubds))
            aud = audDat[x:x+sectionLength]
            x+=sectionLength
            n = len(aud) 
            AudioFreq = fft(aud)
            AudioFreq = AudioFreq[0:int(np.ceil((n+1)/2.0))]
            MagFreq = np.abs(AudioFreq) # Magnitude
            MagFreq = MagFreq / float(n)
            MagFreq = MagFreq**2
            if n % 2 > 0: # ffte odd 
                MagFreq[1:len(MagFreq)] = MagFreq[1:len(MagFreq)] * 2
            else:# fft even
                MagFreq[1:len(MagFreq) -1] = MagFreq[1:len(MagFreq) - 1] * 2
            noNegsKEY = 10*np.log10(MagFreq[:len(MagFreq)//4])
            noNegs2KEY = []
            for neg in noNegsKEY:
                if neg > 0:
                    noNegs2KEY.append(neg)
                else:
                    noNegs2KEY.append(0)
            freqAxisKEY = np.arange(0,int(np.ceil((n+1)/2.0)), 1.0) * (fs / n);
            parsedFreqAxisKEY = freqAxisKEY[:len(freqAxisKEY)//4]
            noNegs3 = noNegs2KEY
            for v in range(1,len(noNegs3)):
                if parsedFreqAxisKEY[v] < 35:
                    noNegs3[v] = 0
            dominantFrqKEY = parsedFreqAxisKEY[noNegs3.index(max(noNegs3))]
            keys.append(dominantFrqKEY)
            print("Dominant frequency for key change "+str(y)+": "+str(dominantFrqKEY))
        timestampsOfKeyChanges = []
        for l in range(0,len(keys)-2):
            k = keys[l]
            larger = max(k, keys[l+1])
            smaller = min(k, keys[l+1])
            val = larger/smaller
            if abs(log2(val)-round(log2(val))>0.15) and abs(k-keys[l+1])>15:
#            if abs(k-keys[keys.index(k)+1])>30 and val-int(val)>0.15 and int(val) != 2:
                nKeyDs+=1
                print("Key change detected for segment "+str(l)+"; switching from "+str(k)[:str(k).index(".")+4]+" to "+str(keys[l+1])[:str(keys[l+1]).index(".")+4])
                segment = l
                timestampsOfKeyChanges.append(int((length/15)*segment))
                if len(timestampsOfKeyChanges)>=2:
                    if abs(timestampsOfKeyChanges[-2]-timestampsOfKeyChanges[-1])<15:
                        nKeyDs-=1
                        print("Key change was less than 15 seconds away from previous key change. Removing.")
                        timestampsOfKeyChanges.pop()
                segMinI = int(((length/15)*segment)/60)
                segSecI = int(((length/15)*segment)%60)
                segMinF = int(((length/15)*(segment+1))/60)
                segSecF = int(((length/15)*(segment+1))%60)
                print("Time stamp: "+str(segMinI)+" min "+str(segSecI)+" sec to "+str(segMinF)+" min "+str(segSecF)+" sec")
        return nKeyDs

        #print(dominantFrqKEY)
    #    if(len(audDat)>1000):
    #        domFrqKEYLeft, nKeyDsL = numOfKeyChanges(audDat[:int(len(audDat)/2)])
    #        domFrqKEYRight, nKeyDsR = numOfKeyChanges(audDat[int(len(audDat)/2):len(audDat)])
    #    else:
    #        domFrqKEYLeft = dominantFrqKEY
    #        domFrqKEYRight = dominantFrqKEY
    #        nKeyDsL = 0
    #        nKeyDsR = 0
    #    nKeyDs = nKeyDsL+nKeyDsR
    #    for o in range(1,len(octaveBounds)):
    #        if domFrqKEYLeft < octaveBounds[o] and domFrqKEYLeft > octaveBounds[o-1]:
    #            octaveLeft = o-1
    #    for o in range(1,len(octaveBounds)):
    #        if domFrqKEYRight < octaveBounds[o] and domFrqKEYRight > octaveBounds[o-1]:
    #            octaveRight = o-1
        #print(domFrqKEYLeft,domFrqKEYRight)
        #if(pitch(float(domFrqKEYLeft))!=pitch(float(domFrqKEYRight))):
    #    if(abs(domFrqKEYLeft-domFrqKEYRight)>20):
    #        nKeyDs = nKeyDs+1
    #    return dominantFrqKEY, nKeyDs

    nKeyDs = int(numOfKeyChanges(Audiodata))
    # nKeyDs = 0
    print("Number of key changes:",nKeyDs)
    keyChanges.append(nKeyDs)

    plt.figure()
    plt.plot(parsedFreqAxis,noNegs2)
    plt.xlabel('Frequency (Hz)'); plt.ylabel('Power spectrum (dB)')
    plt.show()

# rock = ["Dance Macabre.wav"]
genre = "Rock"
genreL = genre.lower()
# rock = listdir(genre+"/")

def mean(m):
    return sum(m)/len(m)

# genreToUse = eval(genre)
# for song in genreToUse:
#     fourierTransform(genre+"/"+song)
fourierTransform("Rock/Dance Macabre.wav")

data.write("BPM:    \n")
for b in bpms:
    data.write(names[bpms.index(b)]+": "+str(b)+"\n")
data.write("\nDominant frequencies:    \n")
for d in domFrqs:
    data.write(names[domFrqs.index(d)]+": "+str(d)[:str(d).index(".")+4]+"\n")
data.write("\nLengths:    \n")
for l in lengths:
    data.write(names[lengths.index(l)]+": "+str(int(l))+"\n")
data.write("\nKey changes:    \n")
for k in range(0,len(keyChanges)):
    data.write(names[k]+": "+str(int(keyChanges[k]))+"\n")
data.write("\nOctave:\n")
for o in range(0,len(octaves)):
    data.write(names[o]+": "+str(int(octaves[o]))+"\n")
data.write("\nAverage BPM for "+genreL+": "+str(mean(bpms))[:str(mean(bpms)).index(".")+4]+"\n")
data.write("\nAverage dominant frequency for "+genreL+": "+str(mean(domFrqs))[:str(mean(domFrqs)).index(".")+4]+"\n")
data.write("\nAverage length for "+genreL+": "+str(mean(lengths))[:str(mean(lengths)).index(".")+4]+"\n")
data.write("\nAverage number of key changes for "+genreL+": "+str(mean(keyChanges))[:str(mean(keyChanges)).index(".")+4]+"\n")
data.write("\nAverage octave for "+genreL+": "+str(mean(octaves))[:str(mean(octaves)).index(".")+4]+"\n")

data.close()
# Out:
# C:\Users\Aiden\Anaconda3\lib\site-packages\scipy\io\wavfile.py:273: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   WavFileWarning)
# BPM: 126
# Dominant frequency: 71.39996306978053
# Pitch of dominant frequency: D2
# Octave: 2
# Length: 3 min, 36 sec
# Working on key change 0/15
# Dominant frequency for key change 0: 37.80735967441072
# Working on key change 1/15
# Dominant frequency for key change 1: 37.80735967441072
# Working on key change 2/15
# Dominant frequency for key change 2: 37.80735967441072
# Working on key change 3/15
# Dominant frequency for key change 3: 88.6326380645526
# Working on key change 4/15
# Dominant frequency for key change 4: 88.0094398281612
# Working on key change 5/15
# Dominant frequency for key change 5: 98.81154259227856
# Working on key change 6/15
# Dominant frequency for key change 6: 37.80735967441072
# Working on key change 7/15
# Dominant frequency for key change 7: 88.42490531908881
# Working on key change 8/15
# ...
